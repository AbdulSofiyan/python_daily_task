# %%
# What will type(10) and type(3.14) return? What is the difference
type(10)
type(3.14)
# type(10) will return integer and type(3.14) wil  return float
# Out:
# float

# %%
# What is the output of len("Python"), len([1,2,3,4]), and len((10,20))?
print(len("Python"))
print(len([1,2,3,4]))
print(len((10,20)))
# Out:
# 6
# 4
# 2

# %%
# Explain what id(5) does. Why do two variables with the same value
# sometimes have the same id() and sometimes different?
id(5)
#id prints the memory address of variables
# Out:
# 140704338453544

# %%
# What is the difference between type() and isinstance()? Give an example.
name = "sofiyan"
print(type(name))
print(isinstance(name,str))
# Out:
# <class 'str'>
# True

# %%
# Predict the output: print(len([[1,2],[3,4]]))print(len([[1,2],[3,4]]))
print(len([[1,2],[3,4]]))
# Out:
# 2

# %%
# What is the output of abs(-25) and abs(7.8)?
print(abs(-25))
print(abs(7.8))
# abs() will give the positive answer for any input
# Out:
# 25
# 7.8

# %%
# What does round(3.678, 2) return? What about round(3.5) and round(2.5)
print(round(3.678,2))
print(round(3.5))
print(round(2.5))
# round will give the round fig value of a number
# Out:
# 3.68
# 4
# 2

# %%
# Calculate pow(3, 4) and pow(2, 3, 5) (with modulo). What is the purpose of the third argument
print(pow(3,4))
print(pow(2,3,5))
# the third argument will be substracted from the answer of first two arguments
# Out:
# 81
# 3

# %%
# Find the output: min(10, 5, 8, 3) and max(-1, -5, 0)
print(min(10,5,8,3))
print(max(-1,-5,0))
# Out:
# 3
# 0

# %%
# What will sum([1, 2, 3, 4, 5]) return? Can sum() work on a list of strings?
sum1 = ([1, 2, 3, 4, 5])
print(sum1)
# Out:
# [1, 2, 3, 4, 5]

# %%
list1 = ["abdul","sofiyan","name",1]
print(sum(list1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 list1 = ["abdul","sofiyan","name",1]
# ----> 2 print(sum(list1))
#
# TypeError: 'list' object is not callable

# %%
# What is the difference between max() and sorted() when applied to a list?
list1 = [21,34,56,76,34,18,71,17]
print(max(list1))
print(sorted(list1))
# max() will give o/p as highest value
# sorted () will give o/p in asscending order
# Out:
# 76
# [17, 18, 21, 34, 34, 56, 71, 76]

# %%
# Predict: sum(range(1, 11))
sum(range(1,11))
# Out:
# 55

# %%
# What is the difference between print("Hello") and print("Hello", end='')?
print("Hello")
print("Hello", end='hl')
# we can add the character at the ending
# Out:
# Hello
# Hellohl

# %%
# Explain how input() works. How do you take integer input from the user?
name = (input("enter a name :"))
# Out:
# enter a name : sofiyan

# %%
# Write code using input() to take name and age from user and print a message
name = input("enter you're name :")
age = int(input("enter you're age :"))
print("welcome")
# Out:
# enter you're name : sofiyan
# enter you're age : 20
# welcome

# %%
# Convert the string "100" to integer and float. What happens if you do int("abc")?
a = "100"
print(int(a))
print(float(a))
# Out:
# 100
# 100.0

# %%
# What will str(500) and list("hello") return?
print(str(500))
print(list("hello"))
# Out:
# 500
# ['h', 'e', 'l', 'l', 'o']

# %%
# Convert the tuple (1,2,3) to a list and then to a set. What will be the output?
tuple1 = (1,2,3)
print(list(tuple1))
print(set(tuple1))
# Out:
# [1, 2, 3]
# {1, 2, 3}

# %%
# What is the output of tuple([1,2,2,3])
tuple([1,2,2,3])
# Out:
# (1, 2, 2, 3)

# %%
# Explain why set([1,1,2,2,3]) returns {1,2,3}
set([1,1,2,2,3])
# set do not allow duplicate values
# Out:
# {1, 2, 3}

# %%
# What happens when you do bool(0), bool(""), bool([])?
print(bool(0))
print(bool(""))
print(bool([]))
# Out:
# False
# False
# False

# %%
# Convert range(5) into a list. What is the result
print(range(5))
list(range(1,5))
# Out:
# range(0, 5)
# [1, 2, 3, 4]

# %%
# What is the output of list(range(5)), list(range(2,10,2))
print(list(range(5)))
print(list(range(2,10,2)))
# Out:
# [0, 1, 2, 3, 4]
# [2, 4, 6, 8]

# %%
# What does sorted([5,1,3,2]) return? Does it modify the original list?
sorted([5,1,3,2])
# Out:
# [1, 2, 3, 5]

# %%
# Explain reversed([1,2,3,4]). How do you convert it to a list
list1 = [1,2,3,4]
list(reversed(list1))
# Out:
# [4, 3, 2, 1]

# %%
# What is the difference between sorted() and reversed()?
list1 = [13,34,35,67,45,89]
print(sorted(list1))
print(list(reversed(list1)))
# Out:
# [13, 34, 35, 45, 67, 89]
# [89, 45, 67, 35, 34, 13]

# %%
# Predict: list(reversed("Python"))
list(reversed("Python"))
# Out:
# ['n', 'o', 'h', 't', 'y', 'P']

# %%
# What is the output of list(enumerate(["a","b","c"]))?
list(enumerate(["a","b","c"]))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
# Explain how zip([1,2,3], ['a','b','c']) works. What if lists have different lengths
print(list(zip([1,2,3], ['a','b','c']))) 
print(list(zip([1,2,3], ['a','b','c','d'])))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
# Write code using enumerate() to print index and value from fruits = ["apple","banana","cherry"].
list(enumerate(["apple","banana","cherry"]))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cherry')]

# %%
# What will dict(zip(['name','age'], ['Sumit', 25])) return

dict(zip(['name','age'], ['Sumit', 25]))
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
# What is the output of all([True, True, False]) and any([False, False, True])
print(all([True, True, False]))
print(any([False, False, True]))
# Out:
# False
# True

# %%
#Explain a practical use case of all() and any() with a list of condition
list1 = [0,0,1]
print(all([list1]))
print(any([list1]))
# Out:
# True

# %%
# Predict: all([]) and any([])

# %%
# How can you use any() to check if any number in a list is even
x = [2,3,4,5]
if any(x % 2 == 0 for x in list1):
    print(f"{x}:even")
# Out:
# [2, 3, 4, 5]:even

# %%
#
