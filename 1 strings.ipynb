# %%
text = "full stack data science"
print(text[0:5])
# Out:
# full

# %%
text = "full stack data science"
print(text[-4:])
# Out:
# ence

# %%
text = "full stack data science"
print(text[1:8])
# Out:
# ull sta

# %%
text = "full stack data science"
print(text[ : :2])
# Out:
# fl tc aasine

# %%
name = "sumit kumar sharma"
print(name[0:5])
print(name[-6: ])
# Out:
# sumit
# sharma

# %%
text = "full stack data science"
print(text.upper())
print(text.lower())
print(text.title())
print(text.capitalize())
# Out:
# FULL STACK DATA SCIENCE
# full stack data science
# Full Stack Data Science
# Full stack data science

# %%
text = "full stack data science"
print(text.title())
print(text)
print(text.title())
# Out:
# Full Stack Data Science
# full stack data science
# Full Stack Data Science

# %%
text = "full 1122 stack"
print(text.lower())
print(text.upper())
print(text)
# no, the string cannot be changed permanently
# Out:
# full 1122 stack
# FULL 1122 STACK
# full 1122 stack

# %%
text = "full stack data science"
print(text.isalpha())
# Out:
# False

# %%
text = input("enter a string")
print(text.isalpha())
# Out:
# enter a string sofiyan
# True

# %%
text = input("enter a digit")
print(text.isdigit())
# Out:
# enter a digit 18
# True

# %%
text = input("enter a string")
print(text.isalnum())
# Out:
# enter a string www22
# True

# %%
text = input("enter a string")
print(text.islower())
# Out:
# enter a string kohli
# True

# %%
text = "wwww1111"
print(text.isalnum())
print("valid"*(text.isalnum()!=-1) or "not valid")
# Out:
# True
# valid

# %%
text = "full stack data science"
print(text.find("data"))
# Out:
# 11

# %%
text = "full stack data science"
print(text.find("ai"))
# Out:
# -1

# %%
text = "full stack data science"
print(text.index("full"))
# Out:
# 0

# %%
text = "full stack data science"
print(text.find("ai"))
print(text.index("ai"))
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 text = "full stack data science"
#       2 print(text.find("ai"))
# ----> 3 print(text.index("ai"))
#
# ValueError: substring not found

# %%
name = "abdul sofiyan"
print(name.upper())
print(name.find(" "))
print(name[0:5])
print(name[-7: ])
# Out:
# ABDUL SOFIYAN
# 5
# abdul
# sofiyan

# %%
num = "7702990749"
print(len(num))
print(num.isdigit())
# Out:
# 10
# True

# %%
text = input("enter a string")
reverse = text [ : :-1]
print("Reversed string:", reverse)
print(text.title())
print(reverse == text)
# Out:
# enter a string shooter
# Reversed string: retoohs
# Shooter
# False
