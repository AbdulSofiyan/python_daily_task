# %%
# Write a program that takes two numbers and performs division. Handle the ZeroDivisionError
try :
    a = 10
    b = 0
    c = a/b
except ZeroDivisionError:
    print("enter correct value")
# Out:
# enter correct value

# %%
# take a number from user and convert it to integer. Handle ValueError if user enters a string.
try:
    a = int(input("enter a value"))
except ValueError:
    print("enter correct value")
# Out:
# enter a value sofi
# enter correct value

# %%
# Access an element from a list using index. Handle IndexError.
try:
    a = [101,102,103,104]
    print(a[3])
except IndexError:
    print("invalid index")
# Out:
# 104

# %%
# Try to open a file that does not exist. Handle FileNotFoundError
try :
    file = open("data.txt","r")
    content = file.read()
    print("content")
except FileNotFoundError:
    print("file not found")
# Out:
# file not found

# %%
# Create a dictionary and access a key that does not exist. Handle KeyError
try :
    a = {"sofiyan":1,"ibrahim":2,"talha":3}
    print(a ["fahad"])
except KeyError:
    print("key not found")
# Out:
# key not found

# %%
# Write a program using try-except to handle multiple exceptions (ValueError and ZeroDivisionError)
try:
    a = 2
    b = 0
    c = a/b
    print(c)
except ValueError and ZeroDivisionError:
    print("enter correct value")
# Out:
# enter correct value

# %%
# Demonstrate the use of else block with try-except.
try :
    a =  input("enter user id")
    password = input("enter password")
    if a == "sofiyan" and password == "admin":
        print("accessed")
except Exception as e:
    print(e)
else :
    if a == "sofiyan" and password == "admin":
        print("login successfully")
    else :
        print("enter correct value")
# Out:
# enter user id sofiyan
# enter password admin
# accessed
# login successfully

# %%
# Demonstrate the use of finally block with an example
try:
    a = 20
    b = "sofiyan"
    print(c)
except Exception as e:
    print(e)
else:
    print(c)
finally:
    print("all process done")
# Out:
# name 'c' is not defined
# all process done

# %%
# Take age as input. Raise an exception if age is negative
try:
    age =  int(input("enter the age"))
    if age >= 0 :
        print("positive")
    else:
        raise ValueError("negative age")
except Exception as e:
    print(f"error :{e}")
# Out:
# enter the age -1
# error :negative age

# %%
# Write a program that handles TypeError when adding string and integer
try:
    a = 2
    b = "ss"
    c = a + b
    print(c)
except TypeError as e:
    print(f"error:{e}")
# Out:
# error:unsupported operand type(s) for +: 'int' and 'str'

# %%
# Handle ZeroDivisionError and ValueError in the same program using multiple except blocks
try:
    num= int(input("enter a value"))
    result = 10/num
except ValueError:
    print("enter correct value")
except ZeroDivisionError:
    print("zero is not divisible")
# Out:
# enter a value 0
# zero is not divisible

# %%
# Use a single except block to handle any exception and print the error message
try:
    a = "sofiyan"
    b = 20
    c = a+b
    print(c)
except Exception as e:
    print(e)
# Out:
# can only concatenate str (not "int") to str

# %%
# Demonstrate nested try-except blocks

# %%
# Write a program that handles IndexError and KeyError separately
try :
    a = {"sofiyan":1,"ibrahim":2,"talha":3}
    print(a ["fahad"])
    print(a[5])
except IndexError:
    print("enter valid index")
except KeyError:
    print("key not found")
# Out:
# key not found

# %%
# Take a list and a dictionary. Perform operations and handle possible exceptions
try :
    a = [1,2,3,4]
    print(a[5])
    b = {"sofiyan":1,"ibrahim":2,"talha":3}
    print(b ["fahad"])
except IndexError:
    print("enter valid index")
except KeyError:
    print("key not found")
# Out:
# enter valid index

# %%
# Create a program that catches AttributeError when calling a non-existing method
try:
    a = 100
    print(a.upper())
except AttributeError as e:
    print(e)
# Out:
# 'int' object has no attribute 'upper'

# %%
try:
    b = "sofiyan"
    print(b.upper())
except AttributeError as e:
    print(e)
# Out:
# SOFIYAN

# %%
# Handle NameError when using a variable that is not defined
