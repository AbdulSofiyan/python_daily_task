# %%
student = {
           "name" : "sofiyan",
           "age" : 20,
           "city" : "hyd"
}
print(student)
# Out:
# {'name': 'sofiyan', 'age': 20, 'city': 'hyd'}

# %%
dict = {"a":1,"b":2,"c":3}
dict.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dict = {"a":1,"b":2}
dict.values()
# Out:
# dict_values([1, 2])

# %%
dict = {"name":"sofiyan","age":20}
print(dict.get("name"))
# Out:
# sofiyan

# %%
tuple = (10,20,30,40,50)
print(type(tuple))
print(len(tuple))
# Out:
# <class 'tuple'>
# 5

# %%
tup = (10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
tup = (10,20,30,40,50)
tup.index(30)
# Out:
# 2

# %%
dict = {}
dict["a"]= 1
dict["b"]=2
dict["c"]=3
print(dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict = {"a": 1,"b":2}
dict.update({"c":3,"d":4})
dict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
student = {'name': 'sofiyan', 'age': 20, 'city': 'hyd'}
student.pop('age')
print(student)
# Out:
# {'name': 'sofiyan', 'city': 'hyd'}

# %%
dict = {"x":1,"y":2,"z":3}
dict.popitem()
# Out:
# ('z', 3)

# %%
dic = {"a": 1,"b":2}
dic1 = dic.copy()
dic1
# Out:
# {'a': 1, 'b': 2}

# %%
keys = ["red","green","blue"]
d = dict.fromkeys(keys,0)
print(d)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %%
tup = ("sofiyan",10,"virat kohli",18)
tup.update(18)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 tup = ("sofiyan",10,"virat kohli",18)
# ----> 2 tup.update(18)
#
# AttributeError: 'tuple' object has no attribute 'update'

# %%
d = {"name":"sofiyan"}
d.setdefault("age",25)
d
# Out:
# {'name': 'sofiyan', 'age': 25}

# %%
a ={}
a.update({"b":2,"c":3,"d":4})
a.popitem()
print(a)
# Out:
# {'b': 2, 'c': 3}

# %%
tup = (10,20,30,20,40,20,50)
print(tup.index(20))
print(tup.count(20))
# Out:
# 1
# 3

# %%
students{}
name1 = input("enter a name")
marks1 = input("enter marks")
name2 = input("enter a name")

marks2 = input("enter marks")
name3 = input("enter a name")
marks3 = input("enter marks")
# Out:
#   Cell In[53], line 1
#     students{}
#             ^
# SyntaxError: invalid syntax
