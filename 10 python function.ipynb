# %%
# Write a function greet() that prints "Hello, Welcome to Python!". 
def greet():
      print("hello welcome to python")

# %%
greet()
# Out:
# hello welcome to python

# %%
# create a function show_date() that prints the current date and time.
def
