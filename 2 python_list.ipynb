# %%
students = ["alice","sofiyan","talha","ibrahim","fahad"]
students
# Out:
# ['alice', 'sofiyan', 'talha', 'ibrahim', 'fahad']

# %%
numbers = [10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
list = []
list.append(10)
list.append(20)
list.append(30)
list
# Out:
# [10, 20, 30]

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list1.extend(list2)
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
number =[10,20,30,40,50]
number.insert(2,100)
number
# Out:
# [10, 20, 100, 30, 40, 50]

# %%
number = [10,20,30,50,50]
number.remove(50)
number
# Out:
# [10, 20, 30, 50]

# %%
list = [5,10,15,20]
list.pop()
list
# Out:
# [5, 10, 15]

# %%
data = [1,2,3,4,5]
data.clear()
data
# Out:
# []

# %%
list = [10,15,25,30,35]
list.index(25)
# Out:
# 2

# %%
list = [7,2,7,5,7,8]
list.count(7)
# Out:
# 3

# %%
list =[45,12,78,23,56]
list.sort()
list
# Out:
# [12, 23, 45, 56, 78]

# %%
list =[45,12,78,23,56]
list.sort(reverse=True)
list
# Out:
# [78, 56, 45, 23, 12]

# %%
fruits = ["apple","mango","banana","orange"]
fruits.reverse()
fruits
# Out:
# ['orange', 'banana', 'mango', 'apple']

# %%
list1 = [1,2,3,4]
list2 = list1.copy()
print(list1)
print(list2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
text = input("enter a text")
word_list = text.split()
print(word_list)
# Out:
# enter a text i love python programming
# ['i', 'love', 'python', 'programming']

# %%
list = [18,17,36,24,52]
list.append(10)
list.append(20)
list.append(30)
list.sort(reverse=True)
print(list)
# Out:
# [52, 36, 30, 24, 20, 18, 17, 10]

# %%
list = ["virat","kohli",30,40,90]
list.insert(0,"python")
list.pop()
print(list)
print(len(list))
# Out:
# ['python', 'virat', 'kohli', 30, 40]
# 5

# %%
cities = [
    input("enter city1"),
    input("enter city2"),
    input("enter city3"),
    input("enter city4"),
    input("enter city5")
  ]
cities.reverse()
print(cities)
# Out:
# enter city1 hyd
# enter city2 bnglr
# enter city3 delhi
# enter city4 mum
# enter city5 kol
# ['kol', 'mum', 'delhi', 'bnglr', 'hyd']

# %%
list = [10,20,30,20,40,20]
list.remove(20)
list.remove(20)
list.remove(20)
print(list)
# Out:
# [10, 30, 40]

# %%
marks = [92,86,88,74,94]
marks.sort()
lowest = marks[0]
highest = marks[-1]
# Out:
# marks
# lowest
# highest

# %%
highest
# Out:
# 94
